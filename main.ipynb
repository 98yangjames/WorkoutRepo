# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("James_Workouts - Workouts.csv")
df
# Out:
#           Date    Activity  Distance   Type  Duration
# 0     9/7/2023     Running       3.5    NaN        30
# 1     9/8/2023     Lifting       NaN   Legs        30
# 2    9/10/2023     Lifting       NaN  Chest        31
# 3    9/11/2023     Lifting       NaN   Back        32
# 4    9/12/2023     Lifting       NaN  Chest        33
# ..         ...         ...       ...    ...       ...
# 252  8/28/2024     Lifting       NaN  Chest        20
# 253  8/28/2024  Basketball       NaN    NaN        30
# 254  8/29/2024     Running       5.0    NaN        41
# 255  8/30/2024     Running       4.0    NaN        37
# 256  8/31/2024     Running      10.0    NaN        98
#
# [257 rows x 5 columns]

# %%
df['Duration'] = df['Duration'].astype(int)
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month

# %%
px.scatter(df, x = 'Date', y = 'Duration', color = 'Activity',title = 'Month vs. Time (min)', trendline="rolling", trendline_options=dict(window=5))

# %%
px.bar(df, x = 'Date', y = 'Duration', color = 'Duration', barmode='stack', title = 'Date vs. Time (min)')

# %%
px.bar(df, x = 'Activity', y = 'Date', color = 'Duration', barmode='stack', title = 'Sept 2023 - Present')

# %%
print(str(df.Duration.sum() / 60)+ " Hours working out since September 2023")
# Out:
# 229.63333333333333 Hours working out since September 2023

# %%
print(str(df[df['Activity'] == 'Running']['Duration'].sum() / 60)+ " Hours Running since September 2023")
# Out:
# 101.75 Hours Running since September 2023

# %%
print(str(df[df['Activity'] == 'Lifting']['Duration'].sum() / 60)+ " Hours Lifting since September 2023")
# Out:
# 52.85 Hours Lifting since September 2023

# %%
print(str(df[df['Activity'] == 'Basketball']['Duration'].sum() / 60)+ " Hours playing Basketball since September 2023")
# Out:
# 33.5 Hours playing Basketball since September 2023

# %%
print(str(df[(df['Activity'] == 'Outdoor') & (df['Type'] == 'Pickleball')]['Duration'].sum() / 60) + " Hours playing Pickleball since September 2023")
# Out:
# 14.05 Hours playing Pickleball since September 2023

# %%
px.scatter(df[df['Activity'] == 'Running'], x = 'Date', y = 'Distance', color = 'Duration', trendline = 'ols')

# %%
df['Duration'] = df['Duration'].astype(int)
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month

# %%
df
# Out:
#           Date    Activity  Distance   Type  Duration  Month  ActivityEncoded
# 0   2023-09-07     Running       3.5    NaN        30      9                7
# 1   2023-09-08     Lifting       NaN   Legs        30      9                5
# 2   2023-09-10     Lifting       NaN  Chest        31      9                5
# 3   2023-09-11     Lifting       NaN   Back        32      9                5
# 4   2023-09-12     Lifting       NaN  Chest        33      9                5
# ..         ...         ...       ...    ...       ...    ...              ...
# 252 2024-08-28     Lifting       NaN  Chest        20      8                5
# 253 2024-08-28  Basketball       NaN    NaN        30      8                0
# 254 2024-08-29     Running       5.0    NaN        41      8                7
# 255 2024-08-30     Running       4.0    NaN        37      8                7
# 256 2024-08-31     Running      10.0    NaN        98      8                7
#
# [257 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['ActivityEncoded'] = le.fit_transform(df['Activity'])
df['DateEncoded'] = le.fit_transform(df['Date'])
df['TypeEncoded'] = le.fit_transform(df['Type'])

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                  Distance  Duration     Month  ActivityEncoded  DateEncoded  \
# Distance         1.000000  0.837941  0.019930        -0.185208     0.335088
# Duration         0.837941  1.000000  0.034860        -0.102545     0.188204
# Month            0.019930  0.034860  1.000000         0.121985    -0.160711
# ActivityEncoded -0.185208 -0.102545  0.121985         1.000000     0.256773
# DateEncoded      0.335088  0.188204 -0.160711         0.256773     1.000000
# TypeEncoded     -0.029787  0.003259  0.100180         0.698932     0.357996
#
#                  TypeEncoded
# Distance           -0.029787
# Duration            0.003259
# Month               0.100180
# ActivityEncoded     0.698932
# DateEncoded         0.357996
# TypeEncoded         1.000000

# %%
# Create the heatmap
fig = px.imshow(correlation_matrix, text_auto=True, color_continuous_scale='RdBu_r', 
                title='Correlation Heatmap')
fig.show()

# %%
correlation_matrix
# Out:
#                  Distance  Duration     Month  ActivityEncoded  DateEncoded  \
# Distance         1.000000  0.837941  0.019930        -0.185208     0.335088
# Duration         0.837941  1.000000  0.034860        -0.102545     0.188204
# Month            0.019930  0.034860  1.000000         0.121985    -0.160711
# ActivityEncoded -0.185208 -0.102545  0.121985         1.000000     0.256773
# DateEncoded      0.335088  0.188204 -0.160711         0.256773     1.000000
# TypeEncoded     -0.029787  0.003259  0.100180         0.698932     0.357996
#
#                  TypeEncoded
# Distance           -0.029787
# Duration            0.003259
# Month               0.100180
# ActivityEncoded     0.698932
# DateEncoded         0.357996
# TypeEncoded         1.000000

# %%
import openai
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 import openai
#
# ModuleNotFoundError: No module named 'openai'
